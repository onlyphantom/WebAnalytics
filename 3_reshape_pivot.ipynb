# %% [markdown]
# # Lecture 3
#
# The documentation covers:
# - Reshaping and Pivot Tables

# %% [markdown]
# ## Reshaping and Pivot Tables

# %%
import numpy as np
import pandas as pd

home = pd.read_csv('data_processed/home.csv')
so = pd.read_csv('data_input/stackoverflow_qa.csv')

# %%
# adding a year and month column
so['questionyear'] = pd.DatetimeIndex(so['creationdate']).year
so['questionmonth'] = pd.DatetimeIndex(so['creationdate']).month

# %%
# top 20
top20 = so.groupby('ans_name').aggregate(np.sum).sort_values(by=['ans_rep','answercount'], ascending=False).head(20)
top20.head()
# Out:
#                       id  score  viewcount  answercount  commentcount  \
# ans_name
# jezrael     228737021995   7860    1785324         7988          5177
# unutbu       29959502937   4003    3511034         1462           926
# EdChum       61904922571   4812    3580513         2692          3123
# piRSquared   81847238788   3762     542888         3192          1978
# MaxU         65214217669   2348     495154         2404          2121
#
#             favoritecount  quest_rep       ans_rep  questionyear  \
# ans_name
# jezrael             856.0  6209834.0  1.015956e+09      10962131
# unutbu             1612.0  3359192.0  4.549854e+08       1972607
# EdChum              898.0  3354967.0  2.315714e+08       3752567
# piRSquared          537.0  3896510.0  1.990539e+08       3910186
# MaxU                360.0  2862882.0  1.312918e+08       3161929
#
#             questionmonth
# ans_name
# jezrael             36140
# unutbu               6278
# EdChum              11192
# piRSquared          12830
# MaxU                 9881

# %%
criteria = so['ans_name'].isin(top20.index)
so_selected = so[criteria]
so_selected.head()
# Out:
#            id         creationdate  score  viewcount  \
# 4     7577546  2011-09-28 01:58:38      9       2488
# 121  10844493  2012-06-01 04:40:16      5       4397
# 127  10943478  2012-06-08 05:24:57     12      11115
# 130  10972410  2012-06-10 21:12:43     19      46428
# 145  11067027  2012-06-16 21:05:01    115      85762
#
#                                                  title  answercount  \
# 4    Using pandas, how do I subsample a large DataF...            1
# 121  DataFrame.apply in python pandas alters both o...            1
# 127     pandas reindex DataFrame with datetime objects            1
# 130         pandas: combine two columns in a DataFrame            5
# 145  Python Pandas - Re-ordering columns in a dataf...           11
#
#      commentcount  favoritecount      quest_name  quest_rep  ans_name  \
# 4               0            5.0    Uri Laserson      958.0      HYRY
# 121             0            1.0        MikeGruz       28.0  BrenBarn
# 127             0            4.0            BFTM      895.0  BrenBarn
# 130             0            5.0            BFTM      895.0  BrenBarn
# 145             2           28.0  pythOnometrist     1068.0  BrenBarn
#
#       ans_rep  questionyear  questionmonth
# 4     54137.0          2011              9
# 121  136870.0          2012              6
# 127  136870.0          2012              6
# 130  136870.0          2012              6
# 145  136870.0          2012              6

# %% [markdown]
# ### Pivot

# %%
# subset only one user with selected columns only
hy = so.loc[so['ans_name'] == 'HYRY', ['title', 'questionyear', 'viewcount', 'commentcount', 'quest_name']]
hy.head()
# Out:
#                                                  title  questionyear  \
# 4    Using pandas, how do I subsample a large DataF...          2011
# 216                     Pandas xaxis auto-format issue          2012
# 367          Grouping data by multiple dates in pandas          2012
# 722  Change Categorical Variable levels to What I p...          2012
# 932    Plot key count per unique value count in pandas          2013
#
#      viewcount  commentcount    quest_name
# 4         2488             0  Uri Laserson
# 216        613             0      joelhoro
# 367        273             0   user1074057
# 722       1382             0   Tom Bennett
# 932       9115             0        monkut

# %%
hy.head(3)
# Out:
#                                                  title  questionyear  \
# 4    Using pandas, how do I subsample a large DataF...          2011
# 216                     Pandas xaxis auto-format issue          2012
# 367          Grouping data by multiple dates in pandas          2012
#
#      viewcount  commentcount    quest_name
# 4         2488             0  Uri Laserson
# 216        613             0      joelhoro
# 367        273             0   user1074057

# %%
# index and columns have to be unique
hy.pivot(index='title', columns='questionyear', values='viewcount').head()
# Out:
# questionyear                                        2011  2012    2013  \
# title
# 3D animation with matplotlib, connect points to...   NaN   NaN     NaN
# Add multi-index to pandas dataframe and keep cu...   NaN   NaN  4723.0
# Adding means to a pandas dataframe                   NaN   NaN     NaN
# Adding values for missing data combinations in ...   NaN   NaN     NaN
# Aggregating overlapping "all-previous-events" f...   NaN   NaN     NaN
#
# questionyear                                          2014   2015  2016  2017
# title
# 3D animation with matplotlib, connect points to...  2970.0    NaN   NaN   NaN
# Add multi-index to pandas dataframe and keep cu...     NaN    NaN   NaN   NaN
# Adding means to a pandas dataframe                     NaN   53.0   NaN   NaN
# Adding values for missing data combinations in ...     NaN  209.0   NaN   NaN
# Aggregating overlapping "all-previous-events" f...   181.0    NaN   NaN   NaN

# %% [markdown]
# If the `values` argument are omitted, and the DataFrame has more than one columns of values not used as index or columns, then the result will have hierarchical columns:

# %%
pivoted = hy.head().pivot(index='title', columns='questionyear')
pivoted
# Out:
#                                                    viewcount                  \
# questionyear                                            2011    2012    2013
# title
# Change Categorical Variable levels to What I pr...       NaN  1382.0     NaN
# Grouping data by multiple dates in pandas                NaN   273.0     NaN
# Pandas xaxis auto-format issue                           NaN   613.0     NaN
# Plot key count per unique value count in pandas          NaN     NaN  9115.0
# Using pandas, how do I subsample a large DataFr...    2488.0     NaN     NaN
#
#                                                    commentcount            \
# questionyear                                               2011 2012 2013
# title
# Change Categorical Variable levels to What I pr...          NaN  0.0  NaN
# Grouping data by multiple dates in pandas                   NaN  0.0  NaN
# Pandas xaxis auto-format issue                              NaN  0.0  NaN
# Plot key count per unique value count in pandas             NaN  NaN  0.0
# Using pandas, how do I subsample a large DataFr...          0.0  NaN  NaN
#
#                                                       quest_name               \
# questionyear                                                2011         2012
# title
# Change Categorical Variable levels to What I pr...           NaN  Tom Bennett
# Grouping data by multiple dates in pandas                    NaN  user1074057
# Pandas xaxis auto-format issue                               NaN     joelhoro
# Plot key count per unique value count in pandas              NaN          NaN
# Using pandas, how do I subsample a large DataFr...  Uri Laserson          NaN
#
#
# questionyear                                          2013
# title
# Change Categorical Variable levels to What I pr...     NaN
# Grouping data by multiple dates in pandas              NaN
# Pandas xaxis auto-format issue                         NaN
# Plot key count per unique value count in pandas     monkut
# Using pandas, how do I subsample a large DataFr...     NaN

# %%
# we can then subset from the pivoted dataframe
pivoted[['viewcount', 'quest_name']]
# Out:
#                                                    viewcount                  \
# questionyear                                            2011    2012    2013
# title
# Change Categorical Variable levels to What I pr...       NaN  1382.0     NaN
# Grouping data by multiple dates in pandas                NaN   273.0     NaN
# Pandas xaxis auto-format issue                           NaN   613.0     NaN
# Plot key count per unique value count in pandas          NaN     NaN  9115.0
# Using pandas, how do I subsample a large DataFr...    2488.0     NaN     NaN
#
#                                                       quest_name               \
# questionyear                                                2011         2012
# title
# Change Categorical Variable levels to What I pr...           NaN  Tom Bennett
# Grouping data by multiple dates in pandas                    NaN  user1074057
# Pandas xaxis auto-format issue                               NaN     joelhoro
# Plot key count per unique value count in pandas              NaN          NaN
# Using pandas, how do I subsample a large DataFr...  Uri Laserson          NaN
#
#
# questionyear                                          2013
# title
# Change Categorical Variable levels to What I pr...     NaN
# Grouping data by multiple dates in pandas              NaN
# Pandas xaxis auto-format issue                         NaN
# Plot key count per unique value count in pandas     monkut
# Using pandas, how do I subsample a large DataFr...     NaN

# %% [markdown]
# ### Stacking and Unstacking

# %% [markdown]
# - `stack`: "pivot" a level of of the (possibly hierarchical) column labels, returning a DataFrame with an index with a new inner-most level of row labels
# - `unstack`: "pivot" a level of the (possibly hierarchical) row index to the column axis, producing a DataFrame with a new inner-most level of column labels

# %%
hy[['questionyear', 'quest_name', 'viewcount']].head()
# Out:
#      questionyear    quest_name  viewcount
# 4            2011  Uri Laserson       2488
# 216          2012      joelhoro        613
# 367          2012   user1074057        273
# 722          2012   Tom Bennett       1382
# 932          2013        monkut       9115

# %%
# stack() compresses a level in the DataFrame's columns
stacked = hy[['questionyear', 'quest_name', 'viewcount']].stack()
stacked.head(10)
# Out:
# 4    questionyear            2011
#      quest_name      Uri Laserson
#      viewcount               2488
# 216  questionyear            2012
#      quest_name          joelhoro
#      viewcount                613
# 367  questionyear            2012
#      quest_name       user1074057
#      viewcount                273
# 722  questionyear            2012
# dtype: object

# %% [markdown]
# If our DataFrame have a `MultiIndex`, we can choose which level to stack or unstack. The `stacked` dataframe above have two levels of index, so we can pass the level as an argument to our `stack` or `unstack` call. The default is to unstack the last level:

# %%
stacked.unstack(0)
# Out:
#                      4         216          367          722     932    \
# questionyear          2011      2012         2012         2012    2013
# quest_name    Uri Laserson  joelhoro  user1074057  Tom Bennett  monkut
# viewcount             2488       613          273         1382    9115
#
#                937          962    1065            1197  1219   ...    27824  \
# questionyear    2013         2013   2013            2013  2013  ...     2016
# quest_name    zzzeek  Kyle Brandt  Einar  John Salvatier  John  ...    marie
# viewcount       9456        11317    163            1148   268  ...      680
#
#                        27926   27950   27952        27980        28395  \
# questionyear            2016    2016    2016         2016         2016
# quest_name    Radical Edward  Lin Ma  Lin Ma  user1934212  user3177938
# viewcount                112     254     204           34          120
#
#                       28807     29357 29464  32894
# questionyear           2016      2016  2016   2017
# quest_name    ShanZhengYang  pizzacat  vera  Marat
# viewcount               367        84    92     99
#
# [3 rows x 201 columns]

# %%
# same as stacked.unstack().head()
stacked.unstack(1).head()
# Out:
#     questionyear    quest_name viewcount
# 4           2011  Uri Laserson      2488
# 216         2012      joelhoro       613
# 367         2012   user1074057       273
# 722         2012   Tom Bennett      1382
# 932         2013        monkut      9115

# %% [markdown]
# Notice that `stack` and `unstack` implicitly sort the index levels involved. Hence a call to `stack` and then `unstack`, or vice versa, will result in a **sorted copy of the original** DataFrame or Series.

# %%
all(hy.stack().unstack() == hy.sort_index())
# Out:
# True

# %%
hybren = so.loc[so['ans_name'].isin(['HYRY','BrenBarn']),
                ['title', 'questionyear', 'viewcount', 'commentcount', 'quest_name','ans_name']]
hybren.head()
# Out:
#                                                  title  questionyear  \
# 4    Using pandas, how do I subsample a large DataF...          2011
# 121  DataFrame.apply in python pandas alters both o...          2012
# 127     pandas reindex DataFrame with datetime objects          2012
# 130         pandas: combine two columns in a DataFrame          2012
# 145  Python Pandas - Re-ordering columns in a dataf...          2012
#
#      viewcount  commentcount      quest_name  ans_name
# 4         2488             0    Uri Laserson      HYRY
# 121       4397             0        MikeGruz  BrenBarn
# 127      11115             0            BFTM  BrenBarn
# 130      46428             0            BFTM  BrenBarn
# 145      85762             2  pythOnometrist  BrenBarn

# %%
x = hybren.groupby(['ans_name', 'questionyear']).sum()
x
# Out:
#                        viewcount  commentcount
# ans_name questionyear
# BrenBarn 2012             635522            11
#          2013             127605            26
#          2014             226402            68
#          2015              62340            69
#          2016              14126            76
#          2017               1066            18
# HYRY     2011               2488             0
#          2012               2268             0
#          2013             215018            51
#          2014             145200            86
#          2015               8457            22
#          2016              11679            38
#          2017                 99             7

# %% [markdown]
# We can also stack or unstack more than one level at a time by passing a list of levels:

# %%
x.unstack(level=['ans_name']).head()
# Out:
#              viewcount           commentcount
# ans_name      BrenBarn      HYRY     BrenBarn  HYRY
# questionyear
# 2011               NaN    2488.0          NaN   0.0
# 2012          635522.0    2268.0         11.0   0.0
# 2013          127605.0  215018.0         26.0  51.0
# 2014          226402.0  145200.0         68.0  86.0
# 2015           62340.0    8457.0         69.0  22.0

# %%
x.unstack(level=['ans_name', 'questionyear']).head()
# Out:
#            ans_name  questionyear
# viewcount  BrenBarn  2012            635522
#                      2013            127605
#                      2014            226402
#                      2015             62340
#                      2016             14126
# dtype: int64

# %% [markdown]
# Unstack takes an optional `fill_value` argument to replace NaN with a specified value:

# %%
x.unstack(level=['ans_name'], fill_value=0).head()
# Out:
#              viewcount         commentcount
# ans_name      BrenBarn    HYRY     BrenBarn HYRY
# questionyear
# 2011                 0    2488            0    0
# 2012            635522    2268           11    0
# 2013            127605  215018           26   51
# 2014            226402  145200           68   86
# 2015             62340    8457           69   22

# %% [markdown]
# ### Reshaping with Melt

# %%
hybren.head()
# Out:
#                                                  title  questionyear  \
# 4    Using pandas, how do I subsample a large DataF...          2011
# 121  DataFrame.apply in python pandas alters both o...          2012
# 127     pandas reindex DataFrame with datetime objects          2012
# 130         pandas: combine two columns in a DataFrame          2012
# 145  Python Pandas - Re-ordering columns in a dataf...          2012
#
#      viewcount  commentcount      quest_name  ans_name
# 4         2488             0    Uri Laserson      HYRY
# 121       4397             0        MikeGruz  BrenBarn
# 127      11115             0            BFTM  BrenBarn
# 130      46428             0            BFTM  BrenBarn
# 145      85762             2  pythOnometrist  BrenBarn

# %% [markdown]
# `melt` melts the dataframe (from a wide format) into a long one, with only the _identified variable_ (`id_vars`) being retained plus two other non-identifier variables: `variable` and `value`.

# %%
hybren.head(2).melt(id_vars=['title','quest_name'])
# Out:
#                                                title    quest_name  \
# 0  Using pandas, how do I subsample a large DataF...  Uri Laserson
# 1  DataFrame.apply in python pandas alters both o...      MikeGruz
# 2  Using pandas, how do I subsample a large DataF...  Uri Laserson
# 3  DataFrame.apply in python pandas alters both o...      MikeGruz
# 4  Using pandas, how do I subsample a large DataF...  Uri Laserson
# 5  DataFrame.apply in python pandas alters both o...      MikeGruz
# 6  Using pandas, how do I subsample a large DataF...  Uri Laserson
# 7  DataFrame.apply in python pandas alters both o...      MikeGruz
#
#        variable     value
# 0  questionyear      2011
# 1  questionyear      2012
# 2     viewcount      2488
# 3     viewcount      4397
# 4  commentcount         0
# 5  commentcount         0
# 6      ans_name      HYRY
# 7      ans_name  BrenBarn

# %% [markdown]
# The name of those non-identifier columns can be customized using `var_name`:

# %%
hybren.head(2).melt(id_vars=['title', 'quest_name', 'ans_name'], var_name='measurement')
# Out:
#                                                title    quest_name  ans_name  \
# 0  Using pandas, how do I subsample a large DataF...  Uri Laserson      HYRY
# 1  DataFrame.apply in python pandas alters both o...      MikeGruz  BrenBarn
# 2  Using pandas, how do I subsample a large DataF...  Uri Laserson      HYRY
# 3  DataFrame.apply in python pandas alters both o...      MikeGruz  BrenBarn
# 4  Using pandas, how do I subsample a large DataF...  Uri Laserson      HYRY
# 5  DataFrame.apply in python pandas alters both o...      MikeGruz  BrenBarn
#
#     measurement  value
# 0  questionyear   2011
# 1  questionyear   2012
# 2     viewcount   2488
# 3     viewcount   4397
# 4  commentcount      0
# 5  commentcount      0

# %% [markdown]
# ### Combining with stats and GroupBy

# %%
hybren.head()
# Out:
#                                                  title  questionyear  \
# 4    Using pandas, how do I subsample a large DataF...          2011
# 121  DataFrame.apply in python pandas alters both o...          2012
# 127     pandas reindex DataFrame with datetime objects          2012
# 130         pandas: combine two columns in a DataFrame          2012
# 145  Python Pandas - Re-ordering columns in a dataf...          2012
#
#      viewcount  commentcount      quest_name  ans_name
# 4         2488             0    Uri Laserson      HYRY
# 121       4397             0        MikeGruz  BrenBarn
# 127      11115             0            BFTM  BrenBarn
# 130      46428             0            BFTM  BrenBarn
# 145      85762             2  pythOnometrist  BrenBarn

# %%
x = hybren.groupby(['ans_name', 'questionyear']).sum()
x.head(8)
# Out:
#                        viewcount  commentcount
# ans_name questionyear
# BrenBarn 2012             635522            11
#          2013             127605            26
#          2014             226402            68
#          2015              62340            69
#          2016              14126            76
#          2017               1066            18
# HYRY     2011               2488             0
#          2012               2268             0

# %%
dat = x.unstack(level=['ans_name'], fill_value=0)
dat.columns.names=['measurement', 'ans_name']
dat.head()
# Out:
# measurement  viewcount         commentcount
# ans_name      BrenBarn    HYRY     BrenBarn HYRY
# questionyear
# 2011                 0    2488            0    0
# 2012            635522    2268           11    0
# 2013            127605  215018           26   51
# 2014            226402  145200           68   86
# 2015             62340    8457           69   22

# %%
dat.stack().head()
# Out:
# measurement            viewcount  commentcount
# questionyear ans_name
# 2011         BrenBarn          0             0
#              HYRY           2488             0
# 2012         BrenBarn     635522            11
#              HYRY           2268             0
# 2013         BrenBarn     127605            26

# %% [markdown]
# We can call `stack` and then sum for the required axis or levels:

# %%
# by default, .sum(level=None) so no level is preserved
dat.stack().sum()
# Out:
# measurement
# viewcount       1452270
# commentcount        472
# dtype: int64

# %%
# preserve first level of index (axis=0, level=0)
dat.stack().sum(axis=0, level=0).head()
# Out:
# measurement   viewcount  commentcount
# questionyear
# 2011               2488             0
# 2012             637790            11
# 2013             342623            77
# 2014             371602           154
# 2015              70797            91

# %%
# preserve second level of index
dat.stack().sum(axis=0, level=1)
# Out:
# measurement  viewcount  commentcount
# ans_name
# BrenBarn       1067061           268
# HYRY            385209           204

# %%
# again, by default level=None so no column level is preserved
dat.stack().sum(axis=1).head()
# Out:
# questionyear  ans_name
# 2011          BrenBarn         0
#               HYRY          2488
# 2012          BrenBarn    635533
#               HYRY          2268
# 2013          BrenBarn    127631
# dtype: int64

# %%
# preserve first level of columns
dat.stack().sum(axis=1, level=0).head()
# Out:
# measurement            viewcount  commentcount
# questionyear ans_name
# 2011         BrenBarn          0             0
#              HYRY           2488             0
# 2012         BrenBarn     635522            11
#              HYRY           2268             0
# 2013         BrenBarn     127605            26

# %% [markdown]
# ### Pivot tables

# %% [markdown]
# While `pandas` allow us to use `pivot()` for general-purpose pivoting on various data types (strings, numerics etc), it also has `pivot_table()` for pivoting with aggregation of numeric data:

# %%
so['questionquarter'] = pd.DatetimeIndex(so['creationdate']).quarter
hybren = so.loc[so['ans_name'].isin(['HYRY','BrenBarn']),
                ['questionyear', 'viewcount', 'commentcount', 'quest_name','ans_name', 'questionmonth', 'questionquarter']]
hybren.head()
# Out:
#      questionyear  viewcount  commentcount      quest_name  ans_name  \
# 4            2011       2488             0    Uri Laserson      HYRY
# 121          2012       4397             0        MikeGruz  BrenBarn
# 127          2012      11115             0            BFTM  BrenBarn
# 130          2012      46428             0            BFTM  BrenBarn
# 145          2012      85762             2  pythOnometrist  BrenBarn
#
#      questionmonth  questionquarter
# 4                9                3
# 121              6                2
# 127              6                2
# 130              6                2
# 145              6                2

# %%
hybren.pivot_table(index=['ans_name', 'questionquarter'], columns='questionyear', values='viewcount').head()
# Out:
# questionyear              2011          2012          2013         2014  \
# ans_name questionquarter
# BrenBarn 1                 NaN           NaN  14894.500000  6118.700000
#          2                 NaN  34442.200000   3452.909091  9357.615385
#          3                 NaN  61660.200000           NaN  1553.642857
#          4                 NaN  17223.333333   6009.000000  1678.076923
# HYRY     1                 NaN           NaN   4312.894737  3319.405405
#
# questionyear                     2015        2016        2017
# ans_name questionquarter
# BrenBarn 1                1308.350000  207.941176  164.000000
#          2                1170.375000  598.909091         NaN
#          3                 964.272727  289.800000  126.666667
#          4                1350.250000  319.250000   30.000000
# HYRY     1                 567.750000  588.250000   99.000000

# %% [markdown]
# Notice that if we specify multiple values (which are potentially not present in the `columns`, the pivot table will include all the data that can be aggregated in an additional level of hierarchy in the columns:

# %%
hybren.pivot_table(index=['ans_name','questionquarter'], 
                   columns='questionyear', 
                   values=['viewcount','commentcount'], 
                   aggfunc=np.sum, 
                   fill_value=0)
# Out:
#                          commentcount                               viewcount  \
# questionyear                     2011 2012 2013 2014 2015 2016 2017      2011
# ans_name questionquarter
# BrenBarn 1                          0    0    4   17   15   20   16         0
#          2                          0    2    5   15   26   15    0         0
#          3                          0    1    0   27   12   11    2         0
#          4                          0    8   17    9   16   30    0         0
# HYRY     1                          0    0    4   31    1   11    7         0
#          2                          0    0    4   38    5    4    0         0
#          3                          0    0    9    3   15    7    0      2488
#          4                          0    0   34   14    1   16    0         0
#
#
# questionyear                2012    2013    2014   2015  2016 2017
# ans_name questionquarter
# BrenBarn 1                     0   59578   61187  26167  3535  656
#          2                172211   37982  121649   9363  6588    0
#          3                308301       0   21751  10607  1449  380
#          4                155010   30045   21815  16203  2554   30
# HYRY     1                     0   81945  122818   2271  7059   99
#          2                     0   12095   13531   3457  1963    0
#          3                   886   17444    4134   1747  1843    0
#          4                  1382  103534    4717    982   814    0

# %% [markdown]
# If we rather omit the missing values instead of filling it with 0, one option is to use `to_string` which will produce a nice table:

# %%
table = hybren.pivot_table(index=['ans_name','questionquarter'], 
                           columns='questionyear', 
                           values='commentcount', 
                           aggfunc=np.sum)
print(table.to_string(na_rep=''))
# Out:
# questionyear              2011  2012  2013  2014  2015  2016  2017
# ans_name questionquarter
# BrenBarn 1                             4.0  17.0  15.0  20.0  16.0
#          2                       2.0   5.0  15.0  26.0  15.0
#          3                       1.0        27.0  12.0  11.0   2.0
#          4                       8.0  17.0   9.0  16.0  30.0   0.0
# HYRY     1                             4.0  31.0   1.0  11.0   7.0
#          2                             4.0  38.0   5.0   4.0
#          3                 0.0   0.0   9.0   3.0  15.0   7.0
#          4                       0.0  34.0  14.0   1.0  16.0

# %% [markdown]
# If we specify `margins=True` to `pivot_table`, a special row and column named `All` will be added with partial group aggregates across all the categories on our rows and columns:

# %%
hybren.pivot_table(index='questionquarter', 
                   columns='questionyear', 
                   values='viewcount',
                   margins=True).head()
# Out:
# questionyear       2011          2012         2013         2014         2015  \
# questionquarter
# 1                   NaN           NaN  6153.173913  3915.000000  1184.916667
# 2                   NaN  34442.200000  3129.812500  4827.857143   854.666667
# 3                2488.0  44169.571429  2492.000000  1125.434783   617.700000
# 4                   NaN  15639.200000  3339.475000  1020.461538  1227.500000
# All              2488.0  28990.454545  3983.988372  2996.790323   969.821918
#
# questionyear           2016        2017          All
# questionquarter
# 1                365.310345  151.000000  2854.023438
# 2                503.000000         NaN  4677.024691
# 3                193.647059  126.666667  4756.794872
# 4                280.666667   30.000000  3272.679612
# All              344.066667  129.444444  3723.769231

# %% [markdown]
# ### Cross Tabulations

# %% [markdown]
# We can use `crosstab()` to compute a cross-tabulation of two or more factors. By default it computes a frequency table unless an array of values and an aggregation function are passed:

# %%
hybren.head()
# Out:
#      questionyear  viewcount  commentcount      quest_name  ans_name  \
# 4            2011       2488             0    Uri Laserson      HYRY
# 121          2012       4397             0        MikeGruz  BrenBarn
# 127          2012      11115             0            BFTM  BrenBarn
# 130          2012      46428             0            BFTM  BrenBarn
# 145          2012      85762             2  pythOnometrist  BrenBarn
#
#      questionmonth  questionquarter
# 4                9                3
# 121              6                2
# 127              6                2
# 130              6                2
# 145              6                2

# %%
pd.crosstab(hybren.questionquarter, hybren.ans_name)
# Out:
# ans_name         BrenBarn  HYRY
# questionquarter
# 1                      55    73
# 2                      48    33
# 3                      38    40
# 4                      48    55

# %%
# frequency tables can also be normalized to show percentages rather than counts
pd.crosstab(hybren.questionquarter, hybren.ans_name, normalize=True)
# Out:
# ans_name         BrenBarn      HYRY
# questionquarter
# 1                0.141026  0.187179
# 2                0.123077  0.084615
# 3                0.097436  0.102564
# 4                0.123077  0.141026

# %%
# normalize values within rows or columns (`columns` or `index` into the normalize argument)
pd.crosstab(hybren.questionquarter, hybren.questionyear, normalize='columns')
# Out:
# questionyear     2011      2012      2013      2014      2015      2016  \
# questionquarter
# 1                 0.0  0.000000  0.267442  0.379032  0.328767  0.386667
# 2                 0.0  0.227273  0.186047  0.225806  0.205479  0.226667
# 3                 1.0  0.318182  0.081395  0.185484  0.273973  0.226667
# 4                 0.0  0.454545  0.465116  0.209677  0.191781  0.160000
#
# questionyear         2017
# questionquarter
# 1                0.555556
# 2                0.000000
# 3                0.333333
# 4                0.111111

# %%
# apply an aggregation function with the specified values
pd.crosstab(hybren.questionquarter, hybren.questionyear, values=hybren.commentcount, aggfunc=np.sum)
# Out:
# questionyear     2011  2012  2013  2014  2015  2016  2017
# questionquarter
# 1                 NaN   NaN   8.0  48.0  16.0  31.0  23.0
# 2                 NaN   2.0   9.0  53.0  31.0  19.0   NaN
# 3                 0.0   1.0   9.0  30.0  27.0  18.0   2.0
# 4                 NaN   8.0  51.0  23.0  17.0  46.0   0.0

# %%
# add margins to crosstab
pd.crosstab(index=hybren.questionyear, 
            columns=hybren.questionquarter, 
            values=hybren.commentcount,
            aggfunc=np.sum,
            normalize=True,
            margins=True)
# Out:
# questionquarter         1         2         3         4       All
# questionyear
# 2011             0.000000  0.000000  0.000000  0.000000  0.000000
# 2012             0.000000  0.004237  0.002119  0.016949  0.023305
# 2013             0.016949  0.019068  0.019068  0.108051  0.163136
# 2014             0.101695  0.112288  0.063559  0.048729  0.326271
# 2015             0.033898  0.065678  0.057203  0.036017  0.192797
# 2016             0.065678  0.040254  0.038136  0.097458  0.241525
# 2017             0.048729  0.000000  0.004237  0.000000  0.052966
# All              0.266949  0.241525  0.184322  0.307203  1.000000

# %% [markdown]
# ### Tiling

# %%
hybren['viewgroup'] = pd.cut(hybren.viewcount, bins=4)
hybren.head(10)
# Out:
#      questionyear  viewcount  commentcount      quest_name  ans_name  \
# 4            2011       2488             0    Uri Laserson      HYRY
# 121          2012       4397             0        MikeGruz  BrenBarn
# 127          2012      11115             0            BFTM  BrenBarn
# 130          2012      46428             0            BFTM  BrenBarn
# 145          2012      85762             2  pythOnometrist  BrenBarn
# 146          2012      24509             0         serguei  BrenBarn
# 216          2012        613             0        joelhoro      HYRY
# 246          2012      20051             0          turtle  BrenBarn
# 258          2012       4951             0            DanB  BrenBarn
# 287          2012     148048             0          bigbug  BrenBarn
#
#      questionmonth  questionquarter              viewgroup
# 4                9                3   (-123.023, 37030.75]
# 121              6                2   (-123.023, 37030.75]
# 127              6                2   (-123.023, 37030.75]
# 130              6                2    (37030.75, 74036.5]
# 145              6                2   (74036.5, 111042.25]
# 146              6                2   (-123.023, 37030.75]
# 216              7                3   (-123.023, 37030.75]
# 246              8                3   (-123.023, 37030.75]
# 258              8                3   (-123.023, 37030.75]
# 287              8                3  (111042.25, 148048.0]

# %%
# specify custom bin-edges and own labels
hybren['viewgroup'] = pd.cut(hybren.viewcount, 
                             bins=[25, 132, 445, 1420, 148048], 
                             include_lowest=True, 
                             labels=['25_per', '50_per', '75_per', 'above_75'])
hybren.tail(6)
# Out:
#        questionyear  viewcount  commentcount          quest_name  ans_name  \
# 35753          2017        133             6                Cleb  BrenBarn
# 36709          2017        328             2          Goofy Gert  BrenBarn
# 46190          2017        227             0  Franck Dernoncourt  BrenBarn
# 46601          2017        102             2          GhostRider  BrenBarn
# 49864          2017         51             0          Leigh Tsai  BrenBarn
# 53778          2017         30             0              K. Lou  BrenBarn
#
#        questionmonth  questionquarter viewgroup
# 35753              3                1    50_per
# 36709              2                1    50_per
# 46190              7                3    50_per
# 46601              8                3    25_per
# 49864              9                3    25_per
# 53778             10                4    25_per

# %%
hybren.viewgroup.value_counts()
# Out:
# 25_per      99
# above_75    98
# 75_per      97
# 50_per      96
# Name: viewgroup, dtype: int64

# %% [markdown]
# ### Dummy Variables

# %%
# notice that questionquarter is treated as an integer and only the categorical variables are encoded as dummy variables
pd.get_dummies(hybren[['questionquarter','viewgroup', 'ans_name']]).head()
# Out:
#      questionquarter  viewgroup_25_per  viewgroup_50_per  viewgroup_75_per  \
# 4                  3                 0                 0                 0
# 121                2                 0                 0                 0
# 127                2                 0                 0                 0
# 130                2                 0                 0                 0
# 145                2                 0                 0                 0
#
#      viewgroup_above_75  ans_name_BrenBarn  ans_name_HYRY
# 4                     1                  0              1
# 121                   1                  1              0
# 127                   1                  1              0
# 130                   1                  1              0
# 145                   1                  1              0

# %%
# we can also prefix the column names
pd.get_dummies(hybren['ans_name'], prefix='person').join(hybren.quest_name).head()
# Out:
#      person_BrenBarn  person_HYRY      quest_name
# 4                  0            1    Uri Laserson
# 121                1            0        MikeGruz
# 127                1            0            BFTM
# 130                1            0            BFTM
# 145                1            0  pythOnometrist

# %% [markdown]
# The `get_dummies()` function is often used along with discretization function like `cut`:

# %%
bins = [25, 132, 445, 1420, 148048]
dum = pd.get_dummies(pd.cut(hybren['viewcount'], bins))
dum.head()
# Out:
#      (25, 132]  (132, 445]  (445, 1420]  (1420, 148048]
# 4            0           0            0               1
# 121          0           0            0               1
# 127          0           0            0               1
# 130          0           0            0               1
# 145          0           0            0               1

# %% [markdown]
# `get_dummies()` also accepts a DataFrame. By default all categorical variables (categorical in the statistical sense, those with object or categorical dtype) are encoded as dummy variables. All non-object columns are included untouched in the output. You can control the columns that are encoded into dummy variables with the `columns` keyword.
#
# Additionally, we can also pass `prefix` or `prefix_sep` as additional arguments. The default uses the column name as the prefix and `_` as the prefix separator.
#
# If we have wanted only _k-1_ levels of a categorical variable (say, to avoid collinearity) then we can specify `drop_first` as an additional argument.
#
# By default new columns will have `np.uint8` dtype. To choose another type, use the `dtype` argument:

# %%
dat = pd.get_dummies(hybren, 
                     columns=['ans_name', 'viewgroup'], 
                     prefix=['answerby', 'vg'], 
                     prefix_sep='',
                     drop_first=True,
                     dtype=bool)
dat.head()
# Out:
#      questionyear  viewcount  commentcount      quest_name  questionmonth  \
# 4            2011       2488             0    Uri Laserson              9
# 121          2012       4397             0        MikeGruz              6
# 127          2012      11115             0            BFTM              6
# 130          2012      46428             0            BFTM              6
# 145          2012      85762             2  pythOnometrist              6
#
#      questionquarter  answerbyHYRY  vg50_per  vg75_per  vgabove_75
# 4                  3          True     False     False        True
# 121                2         False     False     False        True
# 127                2         False     False     False        True
# 130                2         False     False     False        True
# 145                2         False     False     False        True

# %%
dat.dtypes
# Out:
# questionyear        int64
# viewcount           int64
# commentcount        int64
# quest_name         object
# questionmonth       int64
# questionquarter     int64
# answerbyHYRY         bool
# vg50_per             bool
# vg75_per             bool
# vgabove_75           bool
# dtype: object

# %% [markdown]
# ### Categorical Values

# %%
dat['quest_name'] = pd.Categorical(dat['quest_name'])
# equivalent: dat['quest_name'] = dat['quest_name'].astype("category")
dat.dtypes
# Out:
# questionyear          int64
# viewcount             int64
# commentcount          int64
# quest_name         category
# questionmonth         int64
# questionquarter       int64
# answerbyHYRY           bool
# vg50_per               bool
# vg75_per               bool
# vgabove_75             bool
# dtype: object
